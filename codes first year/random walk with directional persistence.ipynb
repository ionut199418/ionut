# %%
import random
import math
import numpy as np
from scipy.stats import wrapcauchy
import matplotlib.pyplot as plt
plt.figure()
def rw2(n):
    #x,y=0,0
    x=np.zeros(n)
    y=np.zeros(n)
    theta=[0]*n
    theta[0]=wrapcauchy.rvs(c,loc=0,size=1)
    for i in range(1,n):
        r=random.weibullvariate(alpha,beta)
        theta[i]=wrapcauchy.rvs(c,loc=theta[i-1],size=1)
        x[i]=x[i-1]+r*math.cos(theta[i])
        y[i]=y[i-1]+r*math.sin(theta[i])
        #plt.plot(x[i],y[i])
        #redraw()
        #x+=r*math.cos(theta[i])
        #y+=r*math.sin(theta[i])
    return(x,y)   
n=100#int(input("how many steps?"))
alpha=2#int(input("what's the scale?"))
beta=5#int(input("what's the shape?"))
c=0.5#float(input("What's the shape parameter for the wrapped Cauchy?"))
#ries=int(input("how many tries?"))
#or i in range(tries):
    #print(rw2(n))
data=rw2(n)
print(len(data))
print(len(data[0]))
# Out:
# 2
# 100

# %%
import matplotlib.pyplot as plt
import random
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from functools import partial
import statistics

# %%
np.asarray(data)
x=data[0]
y=data[1]
plt.plot(x,y)
plt.xlabel("x-coordinate")
plt.ylabel("y-coordinate")
plt.show()
