# %%
import gpflow
import numpy as np
import pandas as pd
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12, 6)
plt = matplotlib.pyplot

from models.GPMove import GPMove

# %%
df = pd.read_csv('constant lengthscale.csv',index_col=0)
X = df[['Latitude','Longitude']].values
L = df['Lengthscale'].values
T=(pd.to_datetime(df['Date'])- pd.datetime(2000,1,1)).dt.days.astype(float).values
T = T-T[0]
#T = T - T.mean()
#T = T/T.std()
T=T[:,None]

plt.plot(T,X[:,0])
#plt.show()
plt.plot(T,X[:,1])
plt.show()
plt.plot(T,L)
plt.show()

# %%
#create model 
with gpflow.defer_build():
    kl = gpflow.kernels.RBF(1, ARD=False, lengthscales=100, variance=0.1) #+ gpflow.kernels.Bias(1)
    kv = gpflow.kernels.RBF(1, ARD=False, lengthscales=100, variance=1) #+ gpflow.kernels.Bias(1)
    m = GPMove(T, X, kl, kv)

# %%
# set priors
m.kern_len.lengthscales.prior = gpflow.priors.Gaussian(50.0, 100.00)
m.kern_len.variance.prior = gpflow.priors.Gaussian(50.00,100.00)
m.kern_var.lengthscales.prior = gpflow.priors.Gaussian(50.0, 100.00)
m.kern_var.variance.prior = gpflow.priors.Gaussian(50.00,100.00)
m.compile()
# Out:
# WARNING:gpflow.logdensities:Shape of x must be 2D at computation.

# %%
# compile and set parameters to MAP
gpflow.train.ScipyOptimizer().minimize(m)
m.as_pandas_table()
# Out:
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: -1946.934518
#   Number of iterations: 1000
#   Number of functions evaluations: 1090
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: -1946.934518
#   Number of iterations: 1000
#   Number of functions evaluations: 1090
#                                   class          prior transform  trainable  \
# GPMove/V_len                  Parameter     N(0.0,1.0)    (none)       True
# GPMove/V_var                  Parameter     N(0.0,1.0)    (none)       True
# GPMove/kern_len/lengthscales  Parameter  N(50.0,100.0)       +ve       True
# GPMove/kern_len/variance      Parameter  N(50.0,100.0)       +ve       True
# GPMove/kern_var/lengthscales  Parameter  N(50.0,100.0)       +ve       True
# GPMove/kern_var/variance      Parameter  N(50.0,100.0)       +ve       True
# GPMove/likelihood/variance    Parameter           None       +ve       True
#
#                                  shape  fixed_shape  \
# GPMove/V_len                  (365, 1)         True
# GPMove/V_var                  (365, 1)         True
# GPMove/kern_len/lengthscales        ()         True
# GPMove/kern_len/variance            ()         True
# GPMove/kern_var/lengthscales        ()         True
# GPMove/kern_var/variance            ()         True
# GPMove/likelihood/variance          ()         True
#
#                                                                           value
# GPMove/V_len                  [[-0.01828067666653728], [0.08192176375457258]...
# GPMove/V_var                  [[-1.0577266873655737], [-0.35934155627119385]...
# GPMove/kern_len/lengthscales                                  34.81077165758966
# GPMove/kern_len/variance                                     62.438522260883886
# GPMove/kern_var/lengthscales                                  33.71359996078218
# GPMove/kern_var/variance                                       76.8942688853951
# GPMove/likelihood/variance                                                1e-06

# %%
ls=m.predict_length()
plt.plot(ls)
plt.plot(L)
plt.axis([0,365,0,18])
plt.show()

# %%
# HMC sampling
s = gpflow.train.HMC()
samples = s.sample(m, 100, epsilon=0.02, lmax=20, lmin=18, thin=5, logprobs=True)#
print('acceptance rate: ', len(set(samples.logprobs))/len(samples.logprobs))
samples = samples.drop('logprobs', axis=1)
# Out:
# WARNING:gpflow.logdensities:Shape of x must be 2D at computation.
# WARNING:gpflow.logdensities:Shape of x must be 2D at computation.
# WARNING:gpflow.logdensities:Shape of x must be 2D at computation.
# acceptance rate:  0.96

# %%
# set values to HMC sample value and predict lengthscale
f_samples = np.zeros((len(samples),len(T)))

for i, s in samples.iterrows():  # also possible as arguments to hmc.sample()
    feed_dict = m.sample_feed_dict(s)
    f_samples[i,:] =m.predict_length(feed_dict=feed_dict)[:,0]

# %%
# plot each sample
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.plot(L,color=cycle[1])
for i in range(len(samples)):
    plt.plot(T, f_samples[i,:], color=cycle[0],lw=1,alpha=0.1)
plt.axis([0,365,0,25])
plt.show()

# %%
#plot confidence intervals
rate_samples = (f_samples[:,:])
plt.plot(L,color=cycle[1])
line, = plt.plot(T, np.mean(rate_samples, 0), color=cycle[0],lw=2)
plt.fill_between(T[:,0],
                 np.squeeze(np.percentile(rate_samples, 5, axis=0)),
                 np.squeeze(np.percentile(rate_samples, 95, axis=0)),
                 color=line.get_color(), alpha = 0.2)
plt.show()

#plt.plot(T,X[:,0])
#plt.ylim(-0.1, np.max(np.percentile(rate_samples, 95, axis=0)))

# %%
# set values to HMC sample value and predict lengthscale
maxT = np.max(T)
xx = T #np.linspace(0,maxT, 2000).reshape(-1,1)
y_samples = []
for i, s in samples.iterrows():  # also possible as arguments to hmc.sample()
    feed_dict = m.sample_feed_dict(s)
    my, vy = m.predict_y(xx,feed_dict=feed_dict)
    y_samples.append(my)

# %%
# plot each sample
matplotlib.rcParams['figure.figsize'] = (12, 6)
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.plot(T, X[:,0], 'k.', mew=0.2)
for i in range(len(y_samples)):
    plt.plot(T, y_samples[i][:,0], color=cycle[0],lw=1,alpha=0.1)
#plt.axis([0,100,-2,2])
plt.show()

# %%
plt.figure(figsize=(8,4))
for i, col in samples.iteritems():
    
    if col.name=='GPMove/likelihood/variance':
        plt.plot(col, label=col.name)
plt.legend(loc=0)
plt.xlabel('hmc iteration')
plt.ylabel('parameter value')
plt.show()
